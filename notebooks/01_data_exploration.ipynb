# %%
# 1. Load dataset
from datasets import load_dataset

dataset = load_dataset("stanfordnlp/imdb")

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })

# %%
# 2. Inspect dataset
print(dataset)
print(dataset["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })
# ...

# %%
# 3. Dataset size
print("Training examples:", len(dataset["train"]))
print("Test examples:", len(dataset["test"]))
# Out:
# Training examples: 25000
# Test examples: 25000

# %%
# 4. Label distribution
from collections import Counter

train_labels = Counter(dataset["train"]["label"])
test_labels = Counter(dataset["test"]["label"])

print("Training labels:", train_labels)
print("Test labels:", test_labels)
# Out:
# Training labels: Counter({0: 12500, 1: 12500})
# Test labels: Counter({0: 12500, 1: 12500})

# %%
# 5. Review length analysis
import numpy as np

train_lengths = [
    len(example["text"].split())
    for example in dataset["train"]
]

print("Average words:", np.mean(train_lengths))
print("Minimum words:", np.min(train_lengths))
print("Maximum words:", np.max(train_lengths))
print("Median words:", np.median(train_lengths))
# Out:
# Average words: 233.7872
# Minimum words: 10
# Maximum words: 2470
# Median words: 174.0

# %%
# 6. Review length visualization
import matplotlib.pyplot as plt

plt.hist(train_lengths, bins=50)
plt.xlabel("Number of words")
plt.ylabel("Number of reviews")
plt.title("IMDb Review Length Distribution")
plt.show()

# %%
# 7. Example reviews
print("NEGATIVE REVIEW:")
print(dataset["train"][0]["text"])

print("\n" + "=" * 80 + "\n")

print("POSITIVE REVIEW:")
print(dataset["train"][1]["text"])
# Out:
# NEGATIVE REVIEW:
# ...
